# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img_array = cv2.imread("train/0/Training_10118481.jpg")

# %%
img_array.shape
# Out:
# (48, 48, 3)

# %%
plt.imshow(img_array)

# %%
Datadirectory = "train/"

# %%
classes = ["0","1","2","3","4","5","6"]

# %%
for category in classes:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array,(img_size,img_size))
plt.imshow(cv2.cvtColor(new_array,cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_array.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# # read all image and converting them to array

# %%
training_Data = []

def create_training_Data():
    for category in classes:
        path = os.path.join(Datadirectory, category)
        class_num = classes.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array,(img_size,img_size))
                training_Data.append([new_array,class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
print(len(training_Data))
# Out:
# 15503

# %%
import random
random.shuffle(training_Data)

# %%
x=[]# data
y = []# label

for features,label in training_Data:
    x.append(features)
    y.append(label)

x = np.array(x).reshape(-1,img_size,img_size,3) ## 4d because mobilenet architecture takes 4 dimensions(it includes depth)

# %%
x.shape
# Out:
# (15503, 224, 224, 3)

# %%
# for i in range(28709):
#     x[i] = x[i]/255.0;
x = x/255.0;

# %%
y = np.array(y)

# %%
y.shape
# Out:
# (15503,)

# %% [markdown]
# # Depp learning model for training - Transfer Learning

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = tf.keras.applications.MobileNetV2()

# %%
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %% [markdown]
# # Transfer Learning - tuning weights

# %%
base_input = model.layers[0].input

# %%
base_output = model.layers[-2].output

# %%
base_output
# Out:
# <KerasTensor: shape=(None, 1280) dtype=float32 (created by layer 'global_average_pooling2d')>

# %%
final_output = layers.Dense(128)(base_output)
final_ouput = layers.Activation('relu')(final_output)
final_output = layers.Dense(64)(final_ouput)
final_ouput = layers.Activation('relu')(final_output)
final_output = layers.Dense(7,activation='softmax')(final_ouput)

# %%
final_output
# Out:
# <KerasTensor: shape=(None, 7) dtype=float32 (created by layer 'dense_2')>

# %%
new_model = keras.Model(inputs = base_input, outputs= final_output)

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# ...

# %%
new_model.compile(loss="sparse_categorical_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# %%
with tf.device('/cpu:0'):
   x1 = tf.convert_to_tensor(x)
   y1 = tf.convert_to_tensor(y)
new_model.fit(x1,y1, epochs = 20)
# Out:
# Epoch 1/20
# 485/485 [==============================] - 112s 201ms/step - loss: 1.3939 - accuracy: 0.4677
# Epoch 2/20
# 485/485 [==============================] - 99s 204ms/step - loss: 1.1850 - accuracy: 0.5523
# Epoch 3/20
# 485/485 [==============================] - 101s 209ms/step - loss: 1.1051 - accuracy: 0.5861
# Epoch 4/20
# 485/485 [==============================] - 103s 213ms/step - loss: 1.0229 - accuracy: 0.6121
# Epoch 5/20
# 485/485 [==============================] - 104s 214ms/step - loss: 0.9627 - accuracy: 0.6377
# Epoch 6/20
# 485/485 [==============================] - 104s 215ms/step - loss: 0.9045 - accuracy: 0.6660
# Epoch 7/20
# 485/485 [==============================] - 104s 215ms/step - loss: 0.8457 - accuracy: 0.6880
# Epoch 8/20
# 485/485 [==============================] - 105s 216ms/step - loss: 0.7837 - accuracy: 0.7109
# Epoch 9/20
# 485/485 [==============================] - 105s 216ms/step - loss: 0.7246 - accuracy: 0.7333
# Epoch 10/20
# ...

# %%
new_model.save('my_model_huge.h5')

# %%
new_model = tf.keras.models.load_model('my_model_huge.h5')

# %%
frame = cv2.imread("sur.jpg")

# %%
frame.shape
# Out:
# (360, 540, 3)

# %%
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (360, 540)

# %%
faces = faceCascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in faces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]
    cv2.rectangle(frame ,(x, y), (x+w, y+h), (255, 0, 0), 2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if len(facess) == 0:
        print("Faces not detected")
    else:
        for (ex,ey,ew,eh) in facess:
            face_roi = roi_color[ey: ey+eh, ex:ex + ew]

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(face_roi, cv2.COLOR_BGR2RGB))

# %%
final_image = cv2.resize(face_roi, (224,224))
final_image = np.expand_dims(final_image,axis=0)
final_image = final_image/255.0

# %%
predictions = new_model.predict(final_image)

# %%
predictions[0]
# Out:
# array([4.3247212e-05, 4.5336266e-05, 3.1425596e-05, 1.5371461e-09,
#        5.3535632e-06, 1.2839033e-08, 9.9987459e-01], dtype=float32)

# %%
np.argmax(predictions)
# Out:
# 6

# %%
import cv2

path = "haarcascade_frontalface_default.xml"
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN

rectangle_bgr = (255, 255, 255)

img = np.zeros((500,500))

text = "Some text in a box"

(text_width, text_height) = cv2.getTextSize(text, font, fontScale=font_scale, thickness=1)[0]

text_offset_x = 10
text_offset_y = img.shape[0] - 25

box_coords = ((text_offset_x, text_offset_y),(text_offset_x+text_width + 2, text_offset_y - text_height - 2))
cv2.rectangle(img, box_coords[0], box_coords[1], rectangle_bgr, cv2.FILLED)
cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale=font_scale, color=(0,0,0), thickness=1)

cap = cv2.VideoCapture(1)

if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("cannot open webcam")

while True:
    ret,frame = cap.read()
    faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for x,y,w,h in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.rectangle(frame ,(x, y), (x+w, y+h), (255, 0, 0), 2)
        facess = faceCascade.detectMultiScale(roi_gray)
        if len(facess) == 0:
            print("Faces not detected")
        else:
            for (ex,ey,ew,eh) in facess:
                face_roi = roi_color[ey: ey+eh, ex:ex + ew]
    final_image = cv2.resize(face_roi, (224,224))
    final_image = np.expand_dims(final_image,axis=0)
    final_image = final_image/255.0
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    predictions = new_model.predict(final_image)
    
    font_scale = 1.5
    font = cv2.FONT_HERSHEY_PLAIN
    
    if np.argmax(predictions) == 0:
        status = "Angry"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
    elif np.argmax(predictions) == 1:
        status = "Disgiust"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
    elif np.argmax(predictions) == 2:
        status = "fear"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
    elif np.argmax(predictions) == 3:
        status = "Happy"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
    elif np.argmax(predictions) == 6:
        status = "Surprise"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
    elif np.argmax(predictions) == 5:
        status = "Sad"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
    else:
        status = "Neutral"
        
        a,b,w1,h1 = 0,0,175,75
        cv2.rectangle(frame,(a, a),(a + w1, b + h1), (0,0,0), -1)
        
        cv2.putText(frame, status, (a + int(w1/10),b + int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status,(100,150),font,3,(0,0,255),2,cv2.LINE_4)
        
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255))
        
    
    cv2.imshow('Face Emotion Reg',frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
        
cap.release()
cv2.destroyAllWindows()
# Out:
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# Faces not detected
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 34
#      31 faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#      32 gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# ...
